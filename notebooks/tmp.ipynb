# %%
import xarray as xr
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# %%
path = Path(
    "/gpfs01/born/animal/DanielG/hypo_sleep/processed_data",
    "HYDO04",
    "2025-02-26_09-05-08",
    "e838",
    "spectra",
)

# %%
tmp = xr.load_dataarray(
    Path(path, "spectra_39_spi-peak_meth-gsp_mtm_psd_ctx_e838.nc"), engine="h5netcdf"
)

# %%
tmp.freq
# Out:
# <xarray.DataArray 'freq' (freq: 2000)> Size: 16kB
# array([0.000000e+00, 6.250000e-02, 1.250000e-01, ..., 1.248125e+02,
#        1.248750e+02, 1.249375e+02])
# Coordinates:
#   * freq     (freq) float64 16kB 0.0 0.0625 0.125 0.1875 ... 124.8 124.9 124.9

# %%
fig, ax = plt.subplots(figsize=(10, 4))
for ch in tmp.channel:
    tmp.sel(channel=ch).mean(dim="trial").plot(ax=ax)
